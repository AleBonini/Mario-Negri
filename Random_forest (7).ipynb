# %%
library(dplyr)   
library(caret)
library(tidyverse)
library(recipes)
library(pROC)
library(caTools)
library(UBL)

set.seed(1)
options(repr.plot.width = 20, repr.plot.height =10, repr.plot.res = 600)



load(file = "C:/Users/abonini/Desktop/Analysis/Sources/LIVERTRANSPLANT/Modello/df_finale.Rdata")

df <- df_finale

# %% [markdown]
# ## Data partition

# %%
#make this example reproducible
set.seed(1)

#use 70% of dataset as training set and 30% as test set
sample <- sample.split(df$deg_cat, SplitRatio = 0.7)
train  <- subset(df, sample == TRUE)
test   <- subset(df, sample == FALSE)


TestClasses <- test$deg_cat
TestData <- subset(test,select= -deg_cat)

# %%
train <- SmoteClassif(deg_cat ~ ., train, k = 27, dist = "HEOM")

#view distribution of response variable in new dataset
table(train$deg_cat)

TrainClasses <- train$deg_cat
TrainData <- subset(train,select= -deg_cat)
# Out:
#    fast NotFast
#     555     555

# %% [markdown]
# ## Models

# %%
ctrl <- trainControl(method = "repeatedcv", 
                 number = 10, 
                 savePredictions = "final",classProbs=TRUE,verboseIter=TRUE, search= "random") 

#summaryFunction = multiClassSummary (to keep all metrics)

# %%
model_rf <- train(x=TrainData, y=TrainClasses, 
               method = "ranger",
               trControl = ctrl)
# Out:
# + Fold01.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold01.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold01.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold01.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold01.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold01.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold02.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold02.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold02.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold02.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold02.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold02.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold03.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold03.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold03.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold03.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold03.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold03.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold04.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold04.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold04.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold04.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold04.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold04.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold05.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold05.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold05.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold05.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold05.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold05.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold06.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold06.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold06.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold06.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold06.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold06.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold07.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold07.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold07.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold07.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold07.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold07.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold08.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold08.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold08.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold08.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold08.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold08.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold09.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold09.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold09.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold09.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold09.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold09.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# + Fold10.Rep1: min.node.size=10, mtry=42, splitrule=gini
# - Fold10.Rep1: min.node.size=10, mtry=42, splitrule=gini
# + Fold10.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# - Fold10.Rep1: min.node.size= 5, mtry=28, splitrule=extratrees
# + Fold10.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# - Fold10.Rep1: min.node.size= 3, mtry=42, splitrule=gini
# Aggregating results
# Selecting tuning parameters
# Fitting mtry = 28, splitrule = extratrees, min.node.size = 5 on full training set

# %%
model_rrf <- train(x=TrainData, y=TrainClasses, 
               method = "RRF",
               trControl = ctrl)
# Out:
# + Fold01.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold01.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold01.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold01.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold01.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold01.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold02.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold02.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold02.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold02.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold02.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold02.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold03.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold03.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold03.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold03.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold03.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold03.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold04.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold04.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold04.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold04.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold04.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold04.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold05.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold05.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold05.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold05.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold05.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold05.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold06.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold06.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold06.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold06.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold06.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold06.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold07.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold07.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold07.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold07.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold07.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold07.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold08.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold08.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold08.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold08.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold08.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold08.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold09.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold09.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold09.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold09.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold09.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold09.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# + Fold10.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# - Fold10.Rep1: mtry=2, coefReg=0.1695, coefImp=0.04701
# + Fold10.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# - Fold10.Rep1: mtry=4, coefReg=0.7036, coefImp=0.20474
# + Fold10.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# - Fold10.Rep1: mtry=6, coefReg=0.1526, coefImp=0.89319
# Aggregating results
# Selecting tuning parameters
# Fitting mtry = 4, coefReg = 0.704, coefImp = 0.205 on full training set

# %% [markdown]
# ## Results

# %%
print(model_rf)
plot(model_rf)
# Out:
# Random Forest
#
# 1110 samples
#   73 predictor
#    2 classes: 'fast', 'NotFast'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 1 times)
# Summary of sample sizes: 999, 999, 999, 999, 999, 999, ...
# Resampling results across tuning parameters:
#
#   min.node.size  mtry  splitrule   Accuracy   Kappa
#    3             42    gini        0.7837800  0.5674352
#    5             28    extratrees  0.7864505  0.5727782
#   10             42    gini        0.7765320  0.5529188
#
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were mtry = 28, splitrule = extratrees
#  and min.node.size = 5.
# plot without title

# %%
print(model_rrf)
plot(model_rrf)
# Out:
# Regularized Random Forest
#
# 1110 samples
#   73 predictor
#    2 classes: 'fast', 'NotFast'
#
# No pre-processing
# Resampling: Cross-Validated (10 fold, repeated 1 times)
# Summary of sample sizes: 998, 999, 998, 999, 999, 1000, ...
# Resampling results across tuning parameters:
#
#   mtry  coefReg    coefImp     Accuracy   Kappa
#   2     0.1694588  0.04701206  0.6992034  0.3983268
#   4     0.7036451  0.20473636  0.7613433  0.5227360
#   6     0.1525607  0.89319130  0.7116697  0.4233980
#
# Accuracy was used to select the optimal model using the largest value.
# The final values used for the model were mtry = 4, coefReg = 0.7036451
#  and coefImp = 0.2047364.
# plot without title

# %%
# collect resamples
results <- resamples(list(ranger=model_rf,rrf=model_rrf))
# summarize the distributions
summary(results)
# boxplots of results
bwplot(results)
# dot plots of results
dotplot(results)
# Out:
# Call:
# summary.resamples(object = results)
#
# Models: ranger, rrf
# Number of resamples: 10
#
# Accuracy
#             Min.  1st Qu.    Median      Mean   3rd Qu.      Max. NA's
# ranger 0.7477477 0.766421 0.7837838 0.7864505 0.8090010 0.8288288    0
# rrf    0.7053571 0.740991 0.7522523 0.7613433 0.7900491 0.8181818    0
#
# Kappa
#             Min.   1st Qu.    Median      Mean   3rd Qu.      Max. NA's
# ranger 0.4949626 0.5328145 0.5673276 0.5727782 0.6177483 0.6579075    0
# rrf    0.4107143 0.4820035 0.5045095 0.5227360 0.5804259 0.6363636    0
# plot without title
# plot without title

# %% [markdown]
# ## Prediction

# %%
pred_rf <- predict(model_rf,TestData)  
pred_rf.prob <- predict(model_rf,TestData, type="prob")


result <- confusionMatrix(TestClasses,  pred_rf) 
result
result$byClass
# Out:
# Confusion Matrix and Statistics
#
#           Reference
# Prediction fast NotFast
#    fast     117      54
#    NotFast   53     252
#
#                Accuracy : 0.7752
#                  95% CI : (0.735, 0.812)
#     No Information Rate : 0.6429
#     P-Value [Acc > NIR] : 2.931e-10
#
#                   Kappa : 0.5111
#
#  Mcnemar's Test P-Value : 1
#
#             Sensitivity : 0.6882
#             Specificity : 0.8235
#          Pos Pred Value : 0.6842
#          Neg Pred Value : 0.8262
#              Prevalence : 0.3571
#          Detection Rate : 0.2458
#    Detection Prevalence : 0.3592
#       Balanced Accuracy : 0.7559
#
#        'Positive' Class : fast
#          Sensitivity          Specificity       Pos Pred Value
#            0.6882353            0.8235294            0.6842105
#       Neg Pred Value            Precision               Recall
#            0.8262295            0.6842105            0.6882353
#                   F1           Prevalence       Detection Rate
#            0.6862170            0.3571429            0.2457983
# Detection Prevalence    Balanced Accuracy
#            0.3592437            0.7558824

# %%
roc_obj <- roc(TestClasses, as.numeric(pred_rf))
plot(roc_obj, main="Curva ROC")
# Out:
# Setting levels: control = fast, case = NotFast
#
# Setting direction: controls < cases
# Plot with title "Curva ROC"

# %%
roc_obj
# Out:
# Call:
# roc.default(response = TestClasses, predictor = as.numeric(pred_rf))
#
# Data: as.numeric(pred_rf) in 171 controls (TestClasses fast) < 305 cases (TestClasses NotFast).
# Area under the curve: 0.7552

# %%
pred_rf.prob
# Out:
#     fast        NotFast
# 1   0.790633333 0.2093667
# 2   0.167633333 0.8323667
# 3   0.869966667 0.1300333
# 4   0.357566667 0.6424333
# 5   0.272400000 0.7276000
# 6   0.969400000 0.0306000
# 7   0.824633333 0.1753667
# 8   0.791433333 0.2085667
# 9   0.032133333 0.9678667
# 10  0.326633333 0.6733667
# 11  0.612166667 0.3878333
# 12  0.448066667 0.5519333
# 13  0.177166667 0.8228333
# 14  0.392800000 0.6072000
# 15  0.133166667 0.8668333
# 16  0.177066667 0.8229333
# 17  0.002200000 0.9978000
# 18  0.533600000 0.4664000
# 19  0.006566667 0.9934333
# 20  0.082433333 0.9175667
# 21  0.165433333 0.8345667
# 22  0.327000000 0.6730000
# 23  0.210900000 0.7891000
# 24  0.485666667 0.5143333
# 25  0.311600000 0.6884000
# 26  0.314133333 0.6858667
# 27  0.209233333 0.7907667
# 28  0.258433333 0.7415667
# 29  0.623400000 0.3766000
# 30  0.328366667 0.6716333
# ... ...         ...
# 447 0.23920000  0.7608000
# 448 0.28696667  0.7130333
# 449 0.43903333  0.5609667
# 450 0.30143333  0.6985667
# 451 0.20760000  0.7924000
# 452 0.36180000  0.6382000
# 453 0.70426667  0.2957333
# 454 0.51780000  0.4822000
# 455 0.37953333  0.6204667
# 456 0.31416667  0.6858333
# 457 0.47976667  0.5202333
# 458 0.30006667  0.6999333
# 459 0.06256667  0.9374333
# 460 0.52733333  0.4726667
# 461 0.38600000  0.6140000
# 462 0.32010000  0.6799000
# 463 0.25193333  0.7480667
# 464 0.16306667  0.8369333
# 465 0.32206667  0.6779333
# 466 0.42683333  0.5731667
# 467 0.51073333  0.4892667
# 468 0.57036667  0.4296333
# 469 0.37733333  0.6226667
# 470 0.27503333  0.7249667
# 471 0.32453333  0.6754667
# 472 0.26956667  0.7304333
# 473 0.38133333  0.6186667
# 474 0.41343333  0.5865667
# 475 0.15576667  0.8442333
# 476 0.20890000  0.7911000
